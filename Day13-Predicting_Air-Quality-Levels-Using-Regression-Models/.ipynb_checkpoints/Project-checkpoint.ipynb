# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cf
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('air_quality_ghana.csv')
df
# Out:
#      Temperature   Humidity  WindSpeed     Pressure  Rainfall  \
# 0      29.490142  72.295862   4.749323  1005.264369  0.523149
# 1      27.585207  68.538915   5.220071  1007.141930  0.070887
# 2      29.943066  57.804836   6.809763  1018.002070  4.234389
# 3      32.569090  89.325762   3.774596  1008.715529  1.840364
# 4      27.297540  70.288741   5.553010  1006.765445  1.024282
# ..           ...        ...        ...          ...       ...
# 495    29.616730  74.007039   3.983427  1012.032111  3.263437
# 496    24.888262  70.930569   8.020081  1009.818071  4.063182
# 497    27.428984  77.635832   5.204803  1011.451951  5.660032
# 498    25.373145  47.930255   4.452018  1011.558185  1.647812
# 499    23.851601  84.043538   5.277020  1010.149945  1.082612
#
#                 DateTime  Latitude  Longitude   PM2.5
# 0    2023-01-01 00:00:00  6.614418   0.321767 -269.81
# 1    2023-01-01 01:00:00  9.132039  -0.381285 -266.47
# 2    2023-01-01 02:00:00  9.809067   0.311513 -269.86
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Humidity     500 non-null    float64
#  2   WindSpeed    500 non-null    float64
#  3   Pressure     500 non-null    float64
#  4   Rainfall     500 non-null    float64
#  5   DateTime     500 non-null    object
#  6   Latitude     500 non-null    float64
#  7   Longitude    500 non-null    float64
#  8   PM2.5        500 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 35.3+ KB

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.describe()
# Out:
#        Temperature    Humidity   WindSpeed     Pressure    Rainfall  \
# count   500.000000  500.000000  500.000000   500.000000  500.000000
# mean     28.020514   65.047511    5.098194  1012.309905    3.055811
# std       2.943760   14.543620    1.496615     4.907705    3.059502
# min      18.276198   40.231601    0.655617   997.393248    0.000035
# 25%      25.899078   51.816102    4.090004  1008.958439    0.901249
# 50%      28.038391   65.215227    5.105360  1012.106458    2.023651
# 75%      29.910350   77.936791    6.048441  1015.698199    4.353320
# max      39.558194   89.896706    8.869564  1027.965538   18.386469
#
#          Latitude   Longitude       PM2.5
# count  500.000000  500.000000  500.000000
# mean     7.731148   -0.989382 -269.741180
# std      1.850000    1.429447    8.583921
# min      4.512949   -3.496733 -291.140000
# 25%      6.127211   -2.219093 -275.487500
# 50%      7.804261   -1.052458 -269.920000
# 75%      9.265547    0.272918 -263.535000
# ...

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
df
# Out:
#      Temperature   Humidity  WindSpeed     Pressure  Rainfall  \
# 0      29.490142  72.295862   4.749323  1005.264369  0.523149
# 1      27.585207  68.538915   5.220071  1007.141930  0.070887
# 2      29.943066  57.804836   6.809763  1018.002070  4.234389
# 3      32.569090  89.325762   3.774596  1008.715529  1.840364
# 4      27.297540  70.288741   5.553010  1006.765445  1.024282
# ..           ...        ...        ...          ...       ...
# 495    29.616730  74.007039   3.983427  1012.032111  3.263437
# 496    24.888262  70.930569   8.020081  1009.818071  4.063182
# 497    27.428984  77.635832   5.204803  1011.451951  5.660032
# 498    25.373145  47.930255   4.452018  1011.558185  1.647812
# 499    23.851601  84.043538   5.277020  1010.149945  1.082612
#
#                DateTime  Latitude  Longitude   PM2.5
# 0   2023-01-01 00:00:00  6.614418   0.321767 -269.81
# 1   2023-01-01 01:00:00  9.132039  -0.381285 -266.47
# 2   2023-01-01 02:00:00  9.809067   0.311513 -269.86
# ...

# %%
df['Month'] = df['DateTime'].dt.month
df['Time'] = df['DateTime'].dt.time
df['Day'] = df['DateTime'].dt.day

# %%
df
# Out:
#      Temperature   Humidity  WindSpeed     Pressure  Rainfall  \
# 0      29.490142  72.295862   4.749323  1005.264369  0.523149
# 1      27.585207  68.538915   5.220071  1007.141930  0.070887
# 2      29.943066  57.804836   6.809763  1018.002070  4.234389
# 3      32.569090  89.325762   3.774596  1008.715529  1.840364
# 4      27.297540  70.288741   5.553010  1006.765445  1.024282
# ..           ...        ...        ...          ...       ...
# 495    29.616730  74.007039   3.983427  1012.032111  3.263437
# 496    24.888262  70.930569   8.020081  1009.818071  4.063182
# 497    27.428984  77.635832   5.204803  1011.451951  5.660032
# 498    25.373145  47.930255   4.452018  1011.558185  1.647812
# 499    23.851601  84.043538   5.277020  1010.149945  1.082612
#
#                DateTime  Latitude  Longitude   PM2.5  Month      Time  Day
# 0   2023-01-01 00:00:00  6.614418   0.321767 -269.81      1  00:00:00    1
# ...

# %%
X = df.drop(columns=['PM2.5', 'DateTime', 'Latitude', 'Longitude','Time','Month'])
y = df['PM2.5']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=9)

# %%
#models 
lin_model = LinearRegression()
dec_model = DecisionTreeRegressor()
rand_model = RandomForestRegressor()
grad_model = GradientBoostingRegressor()

# %%
# Linear model
lin_model.fit(X_train, y_train)
lin_y_pred = lin_model.predict(X_test)

print('MSE: ', mean_squared_error(y_test, lin_y_pred))
print('RMSE: ', np.square(mean_squared_error(y_test, lin_y_pred)))
print('MAE: ', mean_absolute_error(y_test, lin_y_pred))
# Out:
# MSE:  26.830253322381893
# RMSE:  719.8624933431846
# MAE:  4.28412652618757

# %%
# Decision Tree model
dec_model.fit(X_train, y_train)
dec_y_pred = dec_model.predict(X_test)

print('MSE: ', mean_squared_error(y_test, dec_y_pred))
print('RMSE: ', np.square(mean_squared_error(y_test, dec_y_pred)))
print('MAE: ', mean_absolute_error(y_test, dec_y_pred))
# Out:
# MSE:  52.744258999999985
# RMSE:  2781.9568574590794
# MAE:  5.641099999999999

# %%
# Random Forest model
rand_model.fit(X_train, y_train)
rand_y_pred = rand_model.predict(X_test)

print('MSE: ', mean_squared_error(y_test, rand_y_pred))
print('RMSE: ', np.square(mean_squared_error(y_test, rand_y_pred)))
print('MAE: ', mean_absolute_error(y_test, rand_y_pred))
# Out:
# MSE:  32.8292191394998
# RMSE:  1077.7576293093
# MAE:  4.771090999999988

# %%
# Gradient Boosting model
grad_model.fit(X_train, y_train)
grad_y_pred = grad_model.predict(X_test)

print('MSE: ', mean_squared_error(y_test, grad_y_pred))
print('RMSE: ', np.square(mean_squared_error(y_test, grad_y_pred)))
print('MAE: ', mean_absolute_error(y_test, grad_y_pred))
# Out:
# MSE:  33.132431129032504
# RMSE:  1097.757992520082
# MAE:  4.709293115592443

# %%
# Gradient Boosting model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse')
xgb_model.fit(X_train, y_train)
xgb_y_pred = xgb_model.predict(X_test)

print('MSE: ', mean_squared_error(y_test, xgb_y_pred))
print('RMSE: ', np.square(mean_squared_error(y_test, xgb_y_pred)))
print('MAE: ', mean_absolute_error(y_test, xgb_y_pred))
# Out:
# MSE:  40.049170850824886
# RMSE:  1603.9360858385617
# MAE:  5.211494763183594
